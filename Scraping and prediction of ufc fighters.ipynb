# %%
#Script to extract data from UFC website using web scraping.
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import json
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

def clean_record_text(record_text):
    # Clean up the record text if needed, for example, remove extra characters
    return record_text

def extract_numeric(text):
    # Extract numeric value from text
    match = re.search(r'[\d.]+', text)
    return float(match.group()) if match else 0

def get_fighter_details(fighter_url):
    """Scrape detailed information for a single fighter"""
    try:
        response = requests.get(f"https://www.ufc.com{fighter_url}")
        soup = BeautifulSoup(response.text, 'html.parser')

        # Basic info
        name = soup.select_one('h1.hero-profile__name')
        name = name.text.strip() if name else "Unknown"
        print(f"Name: {name}")

        weight_class = soup.select_one('.hero-profile__division-title')
        weight_class = weight_class.text.strip() if weight_class else "Unknown"
        print(f"Weight Class: {weight_class}")

        # Record
        record_text = soup.select_one('.hero-profile__division-body')

        if record_text:
            record_text = record_text.text.strip()
            record_text = clean_record_text(record_text)
        else:
            record_text = "0-0-0"
        print(f"Record Text: {record_text}")

        wins, losses, draws = 0, 0, 0
        record_parts = record_text.split('-')
        if len(record_parts) >= 3:
            try:
                wins = int(re.search(r'\d+', record_parts[0]).group())
            except (ValueError, AttributeError):
                wins = 0
            try:
                losses = int(re.search(r'\d+', record_parts[1]).group())
            except (ValueError, AttributeError):
                losses = 0
            try:
                draws = int(re.search(r'\d+', record_parts[2]).group())
            except (ValueError, AttributeError):
                draws = 0
        print(f"Wins: {wins}, Losses: {losses}, Draws: {draws}")

        # Physical stats
        height_elem = soup.find('div', text=re.compile(r'\bHeight\b', re.IGNORECASE))
        height = height_elem.find_next_sibling('div').text.strip() if height_elem else ""
        print(f"Height: {height}")

        weight_elem = soup.find('div', text=re.compile(r'\bWeight\b', re.IGNORECASE))
        weight = weight_elem.find_next_sibling('div').text.strip() if weight_elem else ""
        print(f"Weight: {weight}")

        reach_elem = soup.find('div', text=re.compile(r'\bReach\b', re.IGNORECASE))
        reach = reach_elem.find_next_sibling('div').text.strip() if reach_elem else ""
        print(f"Reach: {reach}")

        # Performance stats
        striking_accuracy_elem = soup.find('title', text=re.compile(r'\bStriking Accuracy\b', re.IGNORECASE))
        if striking_accuracy_elem:
            striking_accuracy_text = striking_accuracy_elem.text
            striking_accuracy = re.search(r'(\d+%)', striking_accuracy_text).group(1) if striking_accuracy_text else "0%"
        else:
            striking_accuracy = "0%"
        print(f"Striking Accuracy: {striking_accuracy}")

        strikes_landed = soup.find('div', text=re.compile(r'\bSig. Str. Landed\b', re.IGNORECASE))
        strikes_landed = extract_numeric(strikes_landed.find_next('div', class_='c-stat-compare__number').text) if strikes_landed else 0
        print(f"Strikes Landed: {strikes_landed}")

        strikes_absorbed = soup.find('div', text=re.compile(r'\bSig. Str. Absorbed\b', re.IGNORECASE))
        strikes_absorbed = extract_numeric(strikes_absorbed.find_next('div', class_='c-stat-compare__number').text) * 100 if strikes_absorbed else 0
        print(f"Strikes Absorbed: {strikes_absorbed}")

        strike_defense = soup.find('div', text=re.compile(r'\bSig. Str. Defense\b', re.IGNORECASE))
        strike_defense = extract_numeric(strike_defense.find_next('div', class_='c-stat-compare__number').text) if strike_defense else 0
        print(f"Strike Defense: {strike_defense}")

        takedown_avg = soup.find('div', text=re.compile(r'\bTakedown avg\b', re.IGNORECASE))
        takedown_avg = extract_numeric(takedown_avg.find_next('div', class_='c-stat-compare__number').text) if takedown_avg else 0
        print(f"Takedown Avg: {takedown_avg}")

        takedown_accuracy_elem = soup.find('title', text=re.compile(r'\bTakedown Accuracy\b', re.IGNORECASE))
        if takedown_accuracy_elem:
            takedown_accuracy_text = takedown_accuracy_elem.text
            takedown_accuracy = re.search(r'(\d+%)', takedown_accuracy_text).group(1) if takedown_accuracy_text else "0%"
        else:
            takedown_accuracy = "0%"
        print(f"Takedown Accuracy: {takedown_accuracy}")

        takedown_defense = soup.find('div', text=re.compile(r'\bTakedown Defense\b', re.IGNORECASE))
        takedown_defense = extract_numeric(takedown_defense.find_next('div', class_='c-stat-compare__number').text) if takedown_defense else 0
        print(f"Takedown Defense: {takedown_defense}")

        submission_avg = soup.find('div', text=re.compile(r'\bSubmission avg\b', re.IGNORECASE))
        submission_avg = extract_numeric(submission_avg.find_next('div', class_='c-stat-compare__number').text) if submission_avg else 0
        print(f"Submission Avg: {submission_avg}")

        avg_fight_time_elem = soup.find('div', text=re.compile(r'\bAverage fight time\b', re.IGNORECASE))
        avg_fight_time = avg_fight_time_elem.find_previous_sibling('div',
                                                                   class_='c-stat-compare__number').text.strip() if avg_fight_time_elem else "0"
        print(f"Average Fight Time: {avg_fight_time}")

        # KO/TKO percentage
        ko_tko_elem = soup.find('div', text=re.compile(r'\bKO/TKO\b', re.IGNORECASE))
        ko_tko_value = ko_tko_elem.find_next_sibling('div', class_='c-stat-3bar__value').text.strip() if ko_tko_elem else ""
        percentage_match = re.search(r'\((\d+%)\)', ko_tko_value)
        ko_tko_percentage = percentage_match.group(1) if percentage_match else "0%"
        print(f"KO/TKO Percentage: {ko_tko_percentage}")

        # Submissions percentage
        sub_elem = soup.find('div', text=re.compile(r'\bSUB\b', re.IGNORECASE))
        sub_value = sub_elem.find_next_sibling('div', class_='c-stat-3bar__value').text.strip() if sub_elem else ""
        percentage_sub = re.search(r'\((\d+%)\)', sub_value)
        sub_percentage = percentage_sub.group(1) if percentage_sub else "0%"
        print(f"Submission Percentage: {sub_percentage}")

        # Decision percentage
        dec_elem = soup.find('div', text=re.compile(r'\bDEC\b', re.IGNORECASE))
        dec_value = dec_elem.find_next_sibling('div', class_='c-stat-3bar__value').text.strip() if dec_elem else ""
        percentage_dec = re.search(r'\((\d+%)\)', dec_value)
        dec_percentage = percentage_dec.group(1) if percentage_dec else "0%"
        print(f"Decision Percentage: {dec_percentage}")

        # Significant strikes by standing
        sig_stand_elem = soup.find('div', text=re.compile(r'\bStanding\b', re.IGNORECASE))
        stand_value = sig_stand_elem.find_next_sibling('div', class_='c-stat-3bar__value').text.strip() if sig_stand_elem else ""
        percentage_stand = re.search(r'\((\d+%)\)', stand_value)
        stand_percentage = percentage_stand.group(1) if percentage_stand else "0%"
        print(f"Strikes By Standing: {stand_percentage}")

        # Significant strikes by clinch
        sig_clinch_elem = soup.find('div', class_='c-stat-3bar__label', text=re.compile(r'\bClinch\b', re.IGNORECASE))
        clinch_value = sig_clinch_elem.find_next_sibling('div',
                                                         class_='c-stat-3bar__value').text.strip() if sig_clinch_elem else ""
        percentage_clinch = re.search(r'\((\d+%)\)', clinch_value)
        clinch_percentage = percentage_clinch.group(1) if percentage_clinch else "0%"
        print(f"Strikes By Clinch: {clinch_percentage}")

        # Significant strikes by ground
        sig_ground_elem = soup.find('div', class_='c-stat-3bar__label', text=re.compile(r'\bGround\b', re.IGNORECASE))
        ground_value = sig_ground_elem.find_next_sibling('div',class_='c-stat-3bar__value').text.strip() if sig_ground_elem else ""
        percentage_ground = re.search(r'\((\d+%)\)', ground_value)
        ground_percentage = percentage_ground.group(1) if percentage_ground else "0%"
        print(f"Strikes By Ground: {ground_percentage}")

        # Significant strikes to head
        head_percent_elem = soup.find('text', {'id': 'e-stat-body_x5F__x5F_head_percent'})
        head_percentage = head_percent_elem.text.strip() if head_percent_elem else "0%"
        print(f"Strikes To Head: {head_percentage}")

        # Significant strikes to body
        body_percent_elem = soup.find('text', {'id': 'e-stat-body_x5F__x5F_body_percent'})
        body_percentage = body_percent_elem.text.strip() if body_percent_elem else "0%"
        print(f"Strikes To Body: {body_percentage}")

        # Significant strikes to legs
        leg_percent_elem = soup.find('text', {'id': 'e-stat-body_x5F__x5F_leg_percent'})
        leg_percentage = leg_percent_elem.text.strip() if leg_percent_elem else "0%"
        print(f"Strikes To Legs: {leg_percentage}")

        # Get fighter image
        image = soup.select_one('.hero-profile__image-wrap img')
        image_url = image['src'] if image and 'src' in image.attrs else ""
        print(f"Image URL: {image_url}")

        # Assemble fighter data
        fighter_data = {
            "id": fighter_url.split('/')[-1],
            "name": name,
            "weightClass": weight_class,
            "wins": wins,
            "losses": losses,
            "draws": draws,
            "height": height,
            "weight": weight,
            "reach": reach,
            "strikesLandedPerMin": strikes_landed,
            "strikingAccuracy": striking_accuracy,
            "strikesAbsorbedPerMin": strikes_absorbed,
            "strikeDefense": strike_defense,
            "takedownAvgPer15Min": takedown_avg,
            "takedownAccuracy": takedown_accuracy,
            "takedownDefense": takedown_defense,
            "submissionAvgPer15Min": submission_avg,
            "avgFightTime": avg_fight_time,
            "KoTkoPercentage": ko_tko_percentage,
            "SubmissionPercentage": sub_percentage,
            "DecisionPercentage": dec_percentage,
            "StrikesByStanding": stand_percentage,
            "StrikesByClinching": clinch_percentage,
            "StrikesByGround": ground_percentage,
            "StrikesToHead": head_percentage,
            "StrikesToBody": body_percentage,
            "StrikesToLegs": leg_percentage,
            "image": image_url
        }

        return fighter_data
        print('extracted data for',name,':',fighter_data)
    except Exception as e:
        print(f"Error scraping fighter {fighter_url}: {e}")
        return None

def scrape_fighters(target_count=500):
    """Scrape fighters from UFC website until target count is reached"""
    fighters = []
    page = 1

    while len(fighters) < target_count:
        try:
            url = f"https://www.ufc.com/athletes/all?page={page}"
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')

            # Correct selector for the fighter items
            fighter_items = soup.select('.c-listing-athlete-flipcard .c-listing-athlete-flipcard__inner .c-listing-athlete-flipcard__back .c-listing-athlete-flipcard__action')

            if not fighter_items:
                print(f"No fighter items found on page {page}")
                break

            for item in fighter_items:
                try:
                    # Correct selector for the profile link
                    link = item.select_one('a')
                    if link and 'href' in link.attrs:
                        fighter_url = link['href']

                        fighter_data = get_fighter_details(fighter_url)
                        if fighter_data:
                            fighters.append(fighter_data)
                            # Save progress after each fighter
                            with open('ufc_fighters.json', 'w') as f:
                                json.dump(fighters, f, indent=2)

                        # Be nice to the server
                        time.sleep(2)
                except Exception as e:
                    print(f"Error processing fighter item: {e}")
                    continue

            print(f"Completed page {page}")
            page += 1
            # Be nice to the server between pages
            time.sleep(5)

        except Exception as e:
            print(f"Error processing page {page}: {e}")
            break

    print(f"Scraped {len(fighters)} fighters successfully!")
    return fighters

if __name__ == "__main__":
    print("Starting UFC fighter scraper...")
    fighters = scrape_fighters(target_count=500)
    print(f"Completed scraping {len(fighters)} fighters.")

    # Convert the list of dictionaries to a DataFrame
    dataset = pd.DataFrame(fighters)
    print(dataset)

    # Save the DataFrame to a CSV file
    dataset.to_csv('fighters_data.csv', index=False)
    print("Data saved to fighters_data.csv")
# Out:
# Starting UFC fighter scraper...
# Name: Shamil Abdurakhimov
# Weight Class: Heavyweight Division
# Record Text: 20-8-0 (W-L-D)
# Wins: 20, Losses: 8, Draws: 0
# Height: 75.00
# Weight: 263.00
# Reach: 76.00
# Striking Accuracy: 44%
# Strikes Landed: 3.02
# Strikes Absorbed: 101.0
# Strike Defense: 45.0
# Takedown Avg: 0.14
# Takedown Accuracy: 23%
# Takedown Defense: 0.29
# Submission Avg: 55.0
# Average Fight Time: 09:27
# KO/TKO Percentage: 45%
# Submission Percentage: 20%
# Decision Percentage: 35%
# Strikes By Standing: 67%
# Strikes By Clinch: 24%
# Strikes By Ground: 9%
# Strikes To Head: 59%
# Strikes To Body: 19%
# Strikes To Legs: 22%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-02/ABDURAKHIMOV_SHAMIL_L_02_07.png?itok=PHRwbOwY
# <ipython-input-3-3416dff1d0c9>:62: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   height_elem = soup.find('div', text=re.compile(r'\bHeight\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:66: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   weight_elem = soup.find('div', text=re.compile(r'\bWeight\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:70: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   reach_elem = soup.find('div', text=re.compile(r'\bReach\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:75: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   striking_accuracy_elem = soup.find('title', text=re.compile(r'\bStriking Accuracy\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:83: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   strikes_landed = soup.find('div', text=re.compile(r'\bSig. Str. Landed\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:87: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   strikes_absorbed = soup.find('div', text=re.compile(r'\bSig. Str. Absorbed\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:91: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   strike_defense = soup.find('div', text=re.compile(r'\bSig. Str. Defense\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:95: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   takedown_avg = soup.find('div', text=re.compile(r'\bTakedown avg\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:99: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   takedown_accuracy_elem = soup.find('title', text=re.compile(r'\bTakedown Accuracy\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:107: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   takedown_defense = soup.find('div', text=re.compile(r'\bTakedown Defense\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:111: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   submission_avg = soup.find('div', text=re.compile(r'\bSubmission avg\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:115: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   avg_fight_time_elem = soup.find('div', text=re.compile(r'\bAverage fight time\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:121: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   ko_tko_elem = soup.find('div', text=re.compile(r'\bKO/TKO\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:128: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   sub_elem = soup.find('div', text=re.compile(r'\bSUB\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:135: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dec_elem = soup.find('div', text=re.compile(r'\bDEC\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:142: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   sig_stand_elem = soup.find('div', text=re.compile(r'\bStanding\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:149: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   sig_clinch_elem = soup.find('div', class_='c-stat-3bar__label', text=re.compile(r'\bClinch\b', re.IGNORECASE))
# <ipython-input-3-3416dff1d0c9>:157: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   sig_ground_elem = soup.find('div', class_='c-stat-3bar__label', text=re.compile(r'\bGround\b', re.IGNORECASE))
# Streaming output truncated to the last 5000 lines.
# Decision Percentage: 29%
# Strikes By Standing: 94%
# Strikes By Clinch: 6%
# Strikes By Ground: 0%
# Strikes To Head: 59%
# Strikes To Body: 31%
# Strikes To Legs: 9%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-02/BRYZCEK_ROBERT_L_02-10.png?itok=A9mC-jwV
# Name: Lukasz Brzeski
# Weight Class: Heavyweight Division
# Record Text: 9-6-1 (W-L-D)
# Wins: 9, Losses: 6, Draws: 1
# Height: 75.00
# Weight: 234.00
# Reach: 78.00
# Striking Accuracy: 50%
# Strikes Landed: 3.68
# Strikes Absorbed: 43.0
# Strike Defense: 37.0
# Takedown Avg: 0.43
# Takedown Accuracy: 33%
# Takedown Defense: 0.0
# Submission Avg: 55.0
# Average Fight Time: 10:01
# KO/TKO Percentage: 67%
# Submission Percentage: 11%
# Error scraping fighter /athlete/lukasz-brzeski: 'NoneType' object has no attribute 'text'
# Name: Justin Buchholz
# Weight Class: Lightweight Division
# Record Text: 9-5-0 (W-L-D)
# Wins: 9, Losses: 5, Draws: 0
# Height: 72.00
# Weight: 156.00
# Reach:
# Striking Accuracy: 27%
# Strikes Landed: 4.14
# Strikes Absorbed: 0.0
# Strike Defense: 33.0
# Takedown Avg: 0.79
# Takedown Accuracy: 0%
# Takedown Defense: 0.4
# Submission Avg: 51.0
# Average Fight Time: 07:35
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 63%
# Strikes By Clinch: 26%
# Strikes By Ground: 11%
# Strikes To Head: 71%
# Strikes To Body: 16%
# Strikes To Legs: 13%
# Image URL:
# Name: Joaquin Buckley
# Weight Class: Welterweight Division
# Record Text: 21-6-0 (W-L-D)
# Wins: 21, Losses: 6, Draws: 0
# Height: 70.00
# Weight: 171.00
# Reach: 76.00
# Striking Accuracy: 37%
# Strikes Landed: 3.13
# Strikes Absorbed: 178.0
# Strike Defense: 74.0
# Takedown Avg: 0.09
# Takedown Accuracy: 45%
# Takedown Defense: 0.84
# Submission Avg: 59.0
# Average Fight Time: 10:39
# KO/TKO Percentage: 71%
# Submission Percentage: 0%
# Error scraping fighter /athlete/joaquin-buckley: 'NoneType' object has no attribute 'text'
# Name: Martin Buday
# Weight Class: Heavyweight Division
# Record Text: 14-2-0 (W-L-D)
# Wins: 14, Losses: 2, Draws: 0
# Height: 76.00
# Weight: 275.00
# Reach: 77.00
# Striking Accuracy: 54%
# Strikes Landed: 5.54
# Strikes Absorbed: 21.0
# Strike Defense: 100.0
# Takedown Avg: 0.21
# Takedown Accuracy: 25%
# Takedown Defense: 0.42
# Submission Avg: 52.0
# Average Fight Time: 10:14
# KO/TKO Percentage: 50%
# Submission Percentage: 14%
# Decision Percentage: 36%
# Strikes By Standing: 65%
# Strikes By Clinch: 32%
# Strikes By Ground: 3%
# Strikes To Head: 63%
# Strikes To Body: 25%
# Strikes To Legs: 12%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-12/BUDAY_MARTIN_L_12-16.png?itok=icD8smnz
# Completed page 65
# Name: Dylan Budka
# Weight Class: Middleweight Division
# Record Text: 7-5-0 (W-L-D)
# Wins: 7, Losses: 5, Draws: 0
# Height: 72.00
# Weight: 186.00
# Reach: 75.00
# Striking Accuracy: 38%
# Strikes Landed: 1.8
# Strikes Absorbed: 193.0
# Strike Defense: 77.0
# Takedown Avg: 0.39
# Takedown Accuracy: 38%
# Takedown Defense: 0.0
# Submission Avg: 43.0
# Average Fight Time: 09:42
# KO/TKO Percentage: 14%
# Submission Percentage: 29%
# Decision Percentage: 57%
# Strikes By Standing: 49%
# Strikes By Clinch: 41%
# Strikes By Ground: 10%
# Strikes To Head: 68%
# Strikes To Body: 29%
# Strikes To Legs: 2%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-04/BUDKA_DYLAN_L_04-06.png?itok=DwQSJciv
# Name: Paul Buentello
# Weight Class: Heavyweight Division
# Record Text: 25-12-0 (W-L-D)
# Wins: 25, Losses: 12, Draws: 0
# Height: 74.00
# Weight: 246.00
# Reach:
# Striking Accuracy: 46%
# Strikes Landed: 3.83
# Strikes Absorbed: 19.0
# Strike Defense: 39.0
# Takedown Avg: 0.38
# Takedown Accuracy: 33%
# Takedown Defense: 0.76
# Submission Avg: 52.0
# Average Fight Time: 07:52
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 58%
# Strikes By Clinch: 36%
# Strikes By Ground: 6%
# Strikes To Head: 68%
# Strikes To Body: 23%
# Strikes To Legs: 9%
# Image URL:
# Name: Modestas Bukauskas
# Weight Class: Light Heavyweight Division
# Record Text: 17-6-0 (W-L-D)
# Wins: 17, Losses: 6, Draws: 0
# Height: 75.00
# Weight: 203.00
# Reach: 76.00
# Striking Accuracy: 42%
# Strikes Landed: 4.11
# Strikes Absorbed: 37.0
# Strike Defense: 71.0
# Takedown Avg: 0.19
# Takedown Accuracy: 67%
# Takedown Defense: 0.19
# Submission Avg: 50.0
# Average Fight Time: 09:00
# KO/TKO Percentage: 59%
# Submission Percentage: 18%
# Decision Percentage: 24%
# Strikes By Standing: 87%
# Strikes By Clinch: 11%
# Strikes By Ground: 3%
# Strikes To Head: 69%
# Strikes To Body: 20%
# Strikes To Legs: 10%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-02/BUKAUSKAS_MODESTAS_L_02-22.png?itok=P_vHUkFm
# Name: Felipe Bunes
# Weight Class: Flyweight Division
# Record Text: 14-7-0 (W-L-D)
# Wins: 14, Losses: 7, Draws: 0
# Height: 67.00
# Weight: 126.00
# Reach: 69.00
# Striking Accuracy: 53%
# Strikes Landed: 7.86
# Strikes Absorbed: 259.0
# Strike Defense: 0.0
# Takedown Avg: 2.59
# Takedown Accuracy: 25%
# Takedown Defense: 0.0
# Submission Avg: 41.0
# Average Fight Time: 05:48
# KO/TKO Percentage: 14%
# Submission Percentage: 64%
# Decision Percentage: 21%
# Strikes By Standing: 98%
# Strikes By Clinch: 2%
# Strikes By Ground: 0%
# Strikes To Head: 60%
# Strikes To Body: 21%
# Strikes To Legs: 19%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-01/2/BUNES_FELIPE_L_01-11.png?itok=wEck3Ajf
# Name: Wuliji Buren
# Weight Class: Bantamweight Division
# Record Text: 10-8-0 (W-L-D)
# Wins: 10, Losses: 8, Draws: 0
# Height: 69.00
# Weight: 135.50
# Reach: 69.00
# Striking Accuracy: 43%
# Strikes Landed: 3.02
# Strikes Absorbed: 328.0
# Strike Defense: 78.0
# Takedown Avg: 0.37
# Takedown Accuracy: 43%
# Takedown Defense: 0.0
# Submission Avg: 56.0
# Average Fight Time: 10:17
# KO/TKO Percentage: 20%
# Submission Percentage: 40%
# Decision Percentage: 40%
# Strikes By Standing: 70%
# Strikes By Clinch: 14%
# Strikes By Ground: 17%
# Strikes To Head: 53%
# Strikes To Body: 27%
# Strikes To Legs: 20%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/fighter_images/Wuliji_Buren/BUREN_WULIJI_L.png?itok=gxIzdLMM
# Completed page 66
# Name: Shane Burgos
# Weight Class: Featherweight Division
# Record Text: 15-3-0 (W-L-D)
# Wins: 15, Losses: 3, Draws: 0
# Height: 71.00
# Weight: 145.80
# Reach: 75.50
# Striking Accuracy: 52%
# Strikes Landed: 6.78
# Strikes Absorbed: 43.0
# Strike Defense: 92.0
# Takedown Avg: 0.43
# Takedown Accuracy: 44%
# Takedown Defense: 0.64
# Submission Avg: 56.0
# Average Fight Time: 12:46
# KO/TKO Percentage: 28%
# Submission Percentage: 28%
# Decision Percentage: 44%
# Strikes By Standing: 82%
# Strikes By Clinch: 10%
# Strikes By Ground: 8%
# Strikes To Head: 64%
# Strikes To Body: 19%
# Strikes To Legs: 17%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-07/BURGOS_SHANE_L_07-16.png?itok=iClZJFxe
# Name: Joshua Burkman
# Weight Class: Welterweight Division
# Record Text: 29-17-0 (W-L-D)
# Wins: 29, Losses: 17, Draws: 0
# Height: 70.00
# Weight: 170.50
# Reach: 72.00
# Striking Accuracy: 44%
# Strikes Landed: 3.13
# Strikes Absorbed: 252.99999999999997
# Strike Defense: 73.0
# Takedown Avg: 0.3
# Takedown Accuracy: 37%
# Takedown Defense: 0.15
# Submission Avg: 52.0
# Average Fight Time: 10:37
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 67%
# Strikes By Clinch: 23%
# Strikes By Ground: 10%
# Strikes To Head: 48%
# Strikes To Body: 17%
# Strikes To Legs: 36%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/e401625f-d815-4af6-9d80-b7aa96236d40%252FJosh-Burkman_713_LeftFullBodyImage.png?itok=ooCaGErs
# Name: Justin Burlinson
# Weight Class: Welterweight Division
# Record Text: 0-1-0 (W-L-D)
# Wins: 0, Losses: 1, Draws: 0
# Height: 73.00
# Weight: 170.50
# Reach: 74.00
# Striking Accuracy: 40%
# Strikes Landed: 3.09
# Strikes Absorbed: 0.0
# Strike Defense: 100.0
# Takedown Avg: 9.28
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 62.0
# Average Fight Time: 01:37
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 50%
# Strikes By Clinch: 50%
# Strikes By Ground: 0%
# Strikes To Head: 100%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2021-11/71850%252Fprofile-galery%252Ffullbodyright-picture%252FBURLINSON_JUSTIN_R.png?itok=zL2y30DN
# Name: Nate Burnard
# Weight Class: Unknown
# Record Text: 0-0-0
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight: 264.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0
# Strikes Absorbed: 0
# Strike Defense: 0
# Takedown Avg: 0
# Takedown Accuracy: 0%
# Takedown Defense: 0
# Submission Avg: 0
# Average Fight Time: 0
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-07/BURNARD_NATE_L_07-07.png?itok=CBzOqZSw
# Name: Mads Burnell
# Weight Class: Featherweight Division
# Record Text: 9-3-0 (W-L-D)
# Wins: 9, Losses: 3, Draws: 0
# Height: 68.00
# Weight: 146.00
# Reach: 69.00
# Striking Accuracy: 42%
# Strikes Landed: 2.71
# Strikes Absorbed: 345.0
# Strike Defense: 22.0
# Takedown Avg: 0.38
# Takedown Accuracy: 47%
# Takedown Defense: 0.0
# Submission Avg: 51.0
# Average Fight Time: 13:02
# KO/TKO Percentage: 0%
# Submission Percentage: 56%
# Decision Percentage: 44%
# Strikes By Standing: 58%
# Strikes By Clinch: 8%
# Strikes By Ground: 34%
# Strikes To Head: 74%
# Strikes To Body: 16%
# Strikes To Legs: 10%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/2015c6c1-68d2-4e7b-bb08-a6d81f73304b%252FMads-Burnell_636913_LeftFullBodyImage.png?itok=jlW6FyWO
# Name: Mikey Burnett
# Weight Class: Lightweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 66.00
# Weight: 170.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Completed page 67
# Name: Kevin Burns
# Weight Class: Welterweight Division
# Record Text: 8-4-0 (W-L-D)
# Wins: 8, Losses: 4, Draws: 0
# Height: 71.00
# Weight: 171.00
# Reach:
# Striking Accuracy: 39%
# Strikes Landed: 4.3
# Strikes Absorbed: 28.000000000000004
# Strike Defense: 48.0
# Takedown Avg: 0.85
# Takedown Accuracy: 50%
# Takedown Defense: 0.57
# Submission Avg: 53.0
# Average Fight Time: 10:34
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Error scraping fighter /athlete/kevin-burns: 'NoneType' object has no attribute 'text'
# Name: Gilbert Burns
# Weight Class: Welterweight Division
# Record Text: 22-8-0 (W-L-D)
# Wins: 22, Losses: 8, Draws: 0
# Height: 70.00
# Weight: 171.00
# Reach: 71.00
# Striking Accuracy: 49%
# Strikes Landed: 3.57
# Strikes Absorbed: 210.0
# Strike Defense: 54.0
# Takedown Avg: 0.46
# Takedown Accuracy: 38%
# Takedown Defense: 0.2
# Submission Avg: 53.0
# Average Fight Time: 12:44
# KO/TKO Percentage: 27%
# Submission Percentage: 41%
# Decision Percentage: 32%
# Strikes By Standing: 75%
# Strikes By Clinch: 11%
# Strikes By Ground: 15%
# Strikes To Head: 59%
# Strikes To Body: 22%
# Strikes To Legs: 19%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-01/5/BURNS_GILBERT_L_09-07.png?itok=Tb925Ifg
# Name: Herbert Burns
# Weight Class: Featherweight Division
# Record Text: 11-6-0 (W-L-D)
# Wins: 11, Losses: 6, Draws: 0
# Height: 69.00
# Weight: 146.00
# Reach: 73.50
# Striking Accuracy: 37%
# Strikes Landed: 5.17
# Strikes Absorbed: 294.0
# Strike Defense: 67.0
# Takedown Avg: 1.84
# Takedown Accuracy: 35%
# Takedown Defense: 0.37
# Submission Avg: 42.0
# Average Fight Time: 05:50
# KO/TKO Percentage: 9%
# Submission Percentage: 73%
# Decision Percentage: 18%
# Strikes By Standing: 64%
# Strikes By Clinch: 21%
# Strikes By Ground: 14%
# Strikes To Head: 51%
# Strikes To Body: 36%
# Strikes To Legs: 13%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-08/BURNS_HERBERT_L_3-30.png?itok=lxgBNh0r
# Name: Nah-Shon Burrell
# Weight Class: Welterweight Division
# Record Text: 9-3-0 (W-L-D)
# Wins: 9, Losses: 3, Draws: 0
# Height: 71.00
# Weight: 171.00
# Reach: 76.00
# Striking Accuracy: 48%
# Strikes Landed: 3.45
# Strikes Absorbed: 0.0
# Strike Defense: 52.0
# Takedown Avg: 0.31
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 56.0
# Average Fight Time: 11:49
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 66%
# Strikes By Clinch: 22%
# Strikes By Ground: 12%
# Strikes To Head: 71%
# Strikes To Body: 22%
# Strikes To Legs: 7%
# Image URL:
# Name: Martin Buschkamp
# Weight Class: Featherweight Division
# Record Text: 9-0-0 (W-L-D)
# Wins: 9, Losses: 0, Draws: 0
# Height: 69.00
# Weight: 145.00
# Reach: 70.00
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 78%
# Decision Percentage: 22%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Completed page 68
# Name: Bubba Bush
# Weight Class: Middleweight Division
# Record Text: 8-3-0 (W-L-D)
# Wins: 8, Losses: 3, Draws: 0
# Height: 72.00
# Weight: 185.00
# Reach: 73.00
# Striking Accuracy: 56%
# Strikes Landed: 7.01
# Strikes Absorbed: 282.0
# Strike Defense: 60.0
# Takedown Avg: 0.0
# Takedown Accuracy: 50%
# Takedown Defense: 0.0
# Submission Avg: 26.0
# Average Fight Time: 08:00
# KO/TKO Percentage: 50%
# Submission Percentage: 38%
# Decision Percentage: 13%
# Strikes By Standing: 50%
# Strikes By Clinch: 10%
# Strikes By Ground: 40%
# Strikes To Head: 40%
# Strikes To Body: 10%
# Strikes To Legs: 50%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/96967fa8-7754-48d3-aece-e0b4ae3cb7f3%252FBubba-Bush_490461_LeftFullBodyImage.png?itok=xWaCG4jm
# Name: Dakota Bush
# Weight Class: Lightweight Division
# Record Text: 8-4-0 (W-L-D)
# Wins: 8, Losses: 4, Draws: 0
# Height: 70.00
# Weight: 155.50
# Reach: 73.50
# Striking Accuracy: 39%
# Strikes Landed: 4.42
# Strikes Absorbed: 240.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 33%
# Takedown Defense: 0.0
# Submission Avg: 42.0
# Average Fight Time: 09:24
# KO/TKO Percentage: 25%
# Submission Percentage: 50%
# Decision Percentage: 25%
# Strikes By Standing: 94%
# Strikes By Clinch: 4%
# Strikes By Ground: 2%
# Strikes To Head: 48%
# Strikes To Body: 15%
# Strikes To Legs: 37%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2021-06/BUSH_DAKOTA_L_04-17.png?itok=rOx3oRMd
# Name: Murilo Bustamante
# Weight Class: Middleweight Division
# Record Text: 11-1-1 (W-L-D)
# Wins: 11, Losses: 1, Draws: 1
# Height: 73.00
# Weight: 183.00
# Reach:
# Striking Accuracy: 33%
# Strikes Landed: 1.9
# Strikes Absorbed: 246.0
# Strike Defense: 55.0
# Takedown Avg: 1.23
# Takedown Accuracy: 33%
# Takedown Defense: 0.21
# Submission Avg: 60.0
# Average Fight Time: 12:25
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 57%
# Strikes By Clinch: 13%
# Strikes By Ground: 30%
# Strikes To Head: 90%
# Strikes To Body: 8%
# Strikes To Legs: 2%
# Image URL:
# Name: Todd Butler
# Weight Class: Lightweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 0.00
# Weight: 0.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Jesse Butler
# Weight Class: Bantamweight Division
# Record Text: 12-6-0 (W-L-D)
# Wins: 12, Losses: 6, Draws: 0
# Height: 70.00
# Weight: 136.00
# Reach: 73.00
# Striking Accuracy: 35%
# Strikes Landed: 4.62
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 40.0
# Average Fight Time: 07:42
# KO/TKO Percentage: 8%
# Submission Percentage: 67%
# Decision Percentage: 25%
# Strikes By Standing: 100%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 55%
# Strikes To Body: 29%
# Strikes To Legs: 16%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-06/BUTLER_JESSE_L_06-03.png?itok=9xeEJP4e
# Name: JP Buys
# Weight Class: Bantamweight Division
# Record Text: 9-6-0 (W-L-D)
# Wins: 9, Losses: 6, Draws: 0
# Height: 65.00
# Weight: 136.00
# Reach: 67.00
# Striking Accuracy: 40%
# Strikes Landed: 3.02
# Strikes Absorbed: 155.0
# Strike Defense: 25.0
# Takedown Avg: 2.32
# Takedown Accuracy: 25%
# Takedown Defense: 0.0
# Submission Avg: 40.0
# Average Fight Time: 06:28
# KO/TKO Percentage: 33%
# Submission Percentage: 56%
# Decision Percentage: 11%
# Strikes By Standing: 52%
# Strikes By Clinch: 16%
# Strikes By Ground: 32%
# Strikes To Head: 67%
# Strikes To Body: 15%
# Strikes To Legs: 18%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-08/BUYS_JP_L_08-12.png?itok=1VAxDpLb
# Completed page 69
# Name: Dennis Buzukja
# Weight Class: Featherweight Division
# Record Text: 12-5-0 (W-L-D)
# Wins: 12, Losses: 5, Draws: 0
# Height: 69.00
# Weight: 155.50
# Reach: 70.50
# Striking Accuracy: 43%
# Strikes Landed: 4.82
# Strikes Absorbed: 63.0
# Strike Defense: 75.0
# Takedown Avg: 0.21
# Takedown Accuracy: 27%
# Takedown Defense: 0.42
# Submission Avg: 49.0
# Average Fight Time: 11:52
# KO/TKO Percentage: 42%
# Submission Percentage: 8%
# Decision Percentage: 50%
# Strikes By Standing: 83%
# Strikes By Clinch: 11%
# Strikes By Ground: 6%
# Strikes To Head: 55%
# Strikes To Body: 26%
# Strikes To Legs: 19%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-08/BUZUKJA_DENNIS_L_08-24.png?itok=sjBPpfGu
# Name: Charles Byrd
# Weight Class: Middleweight Division
# Record Text: 10-7-0 (W-L-D)
# Wins: 10, Losses: 7, Draws: 0
# Height: 70.00
# Weight: 184.50
# Reach: 73.00
# Striking Accuracy: 56%
# Strikes Landed: 2.63
# Strikes Absorbed: 250.0
# Strike Defense: 40.0
# Takedown Avg: 1.5
# Takedown Accuracy: 50%
# Takedown Defense: 0.0
# Submission Avg: 56.0
# Average Fight Time: 05:00
# KO/TKO Percentage: 30%
# Submission Percentage: 50%
# Decision Percentage: 20%
# Strikes By Standing: 47%
# Strikes By Clinch: 15%
# Strikes By Ground: 39%
# Strikes To Head: 83%
# Strikes To Body: 7%
# Strikes To Legs: 11%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/ufc-fighter-container/67587/profile-galery/fullbodyleft-picture/BYRD_CHARLES_L.png?VersionId=qAx8l64VSdMJuGwxGJa0rGCRfL2Dek0D&itok=08jdJRcN
# Name: Steve Byrnes
# Weight Class: Middleweight Division
# Record Text: 6-1-0 (W-L-D)
# Wins: 6, Losses: 1, Draws: 0
# Height: 72.00
# Weight: 186.00
# Reach:
# Striking Accuracy: 51%
# Strikes Landed: 2.67
# Strikes Absorbed: 300.0
# Strike Defense: 0.0
# Takedown Avg: 4.0
# Takedown Accuracy: 60%
# Takedown Defense: 0.0
# Submission Avg: 27.0
# Average Fight Time: 15:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Error scraping fighter /athlete/kevin-byorns-2: 'NoneType' object has no attribute 'text'
# Name: Yan Cabral
# Weight Class: Lightweight Division
# Record Text: 12-3-0 (W-L-D)
# Wins: 12, Losses: 3, Draws: 0
# Height: 71.00
# Weight: 156.00
# Reach: 73.00
# Striking Accuracy: 48%
# Strikes Landed: 1.98
# Strikes Absorbed: 289.0
# Strike Defense: 38.0
# Takedown Avg: 1.24
# Takedown Accuracy: 36%
# Takedown Defense: 0.21
# Submission Avg: 62.0
# Average Fight Time: 12:07
# KO/TKO Percentage: 0%
# Submission Percentage: 100%
# Decision Percentage: 0%
# Strikes By Standing: 48%
# Strikes By Clinch: 16%
# Strikes By Ground: 36%
# Strikes To Head: 77%
# Strikes To Body: 11%
# Strikes To Legs: 12%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/4da6245b-b7a0-4edf-94b6-65f1dfaec508%252Fyan-cabral_309186_LeftFullBodyImage.png?itok=iZ46GAWU
# Name: Alex Caceres
# Weight Class: Featherweight Division
# Record Text: 21-15-0 (W-L-D)
# Wins: 21, Losses: 15, Draws: 0
# Height: 70.00
# Weight: 158.80
# Reach: 73.50
# Striking Accuracy: 50%
# Strikes Landed: 3.09
# Strikes Absorbed: 54.0
# Strike Defense: 65.0
# Takedown Avg: 0.67
# Takedown Accuracy: 68%
# Takedown Defense: 0.21
# Submission Avg: 63.0
# Average Fight Time: 12:02
# KO/TKO Percentage: 19%
# Submission Percentage: 33%
# Decision Percentage: 48%
# Strikes By Standing: 86%
# Strikes By Clinch: 8%
# Strikes By Ground: 6%
# Strikes To Head: 63%
# Strikes To Body: 25%
# Strikes To Legs: 12%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-06/CACERES_ALEX_L_06-03.png?itok=66f6qyRO
# Completed page 70
# Name: Vince Cachero
# Weight Class: Bantamweight Division
# Record Text: 7-4-0 (W-L-D)
# Wins: 7, Losses: 4, Draws: 0
# Height: 66.00
# Weight: 135.50
# Reach: 68.00
# Striking Accuracy: 46%
# Strikes Landed: 6.51
# Strikes Absorbed: 0.0
# Strike Defense: 19.0
# Takedown Avg: 0.54
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 43.0
# Average Fight Time: 13:49
# KO/TKO Percentage: 29%
# Submission Percentage: 29%
# Decision Percentage: 43%
# Strikes By Standing: 79%
# Strikes By Clinch: 18%
# Strikes By Ground: 3%
# Strikes To Head: 73%
# Strikes To Body: 14%
# Strikes To Legs: 13%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2021-02/71684%252Fprofile-galery%252Ffullbodyleft-picture%252FCACHERO_VINCE_L_08-01.png?itok=55UffkZg
# Name: Priscila Cachoeira
# Weight Class: Women's Bantamweight Division
# Record Text: 13-6-0 (W-L-D)
# Wins: 13, Losses: 6, Draws: 0
# Height: 67.00
# Weight: 135.00
# Reach: 65.00
# Striking Accuracy: 44%
# Strikes Landed: 7.15
# Strikes Absorbed: 15.0
# Strike Defense: 66.0
# Takedown Avg: 0.0
# Takedown Accuracy: 33%
# Takedown Defense: 0.45
# Submission Avg: 44.0
# Average Fight Time: 09:07
# KO/TKO Percentage: 62%
# Submission Percentage: 0%
# Decision Percentage: 38%
# Strikes By Standing: 84%
# Strikes By Clinch: 10%
# Strikes By Ground: 6%
# Strikes To Head: 75%
# Strikes To Body: 19%
# Strikes To Legs: 6%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-01/CACHOEIRA_PRISCILA_L_01-20.png?itok=Y8pRvGJt
# Name: Ricky Calatayud
# Weight Class: Flyweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight:
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Nicolle Caliari
# Weight Class: Women's Flyweight Division
# Record Text: 8-3-0 (W-L-D)
# Wins: 8, Losses: 3, Draws: 0
# Height: 63.00
# Weight: 125.50
# Reach: 62.00
# Striking Accuracy: 42%
# Strikes Landed: 5.57
# Strikes Absorbed: 380.0
# Strike Defense: 0.0
# Takedown Avg: 1.52
# Takedown Accuracy: 29%
# Takedown Defense: 0.0
# Submission Avg: 56.0
# Average Fight Time: 09:53
# KO/TKO Percentage: 63%
# Submission Percentage: 38%
# Decision Percentage: 0%
# Strikes By Standing: 91%
# Strikes By Clinch: 7%
# Strikes By Ground: 3%
# Strikes To Head: 55%
# Strikes To Body: 32%
# Strikes To Legs: 13%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-01/2/CALIARI_NICOLLE_L_01-11.png?itok=ziDkqsZg
# Name: Taylor Callens
# Weight Class: Lightweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight:
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Cynthia Calvillo
# Weight Class: Women's Strawweight Division
# Record Text: 9-6-1 (W-L-D)
# Wins: 9, Losses: 6, Draws: 1
# Height: 64.00
# Weight: 127.60
# Reach: 64.00
# Striking Accuracy: 38%
# Strikes Landed: 4.12
# Strikes Absorbed: 180.0
# Strike Defense: 78.0
# Takedown Avg: 0.81
# Takedown Accuracy: 44%
# Takedown Defense: 0.0
# Submission Avg: 64.0
# Average Fight Time: 12:50
# KO/TKO Percentage: 22%
# Submission Percentage: 33%
# Decision Percentage: 44%
# Strikes By Standing: 87%
# Strikes By Clinch: 3%
# Strikes By Ground: 11%
# Strikes To Head: 54%
# Strikes To Body: 30%
# Strikes To Legs: 16%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-04/CALVILLO_CYNTHIA_L_04-08.png?itok=7Un49b0G
# Completed page 71
# Name: Frank Camacho
# Weight Class: Lightweight Division
# Record Text: 22-10-0 (W-L-D)
# Wins: 22, Losses: 10, Draws: 0
# Height: 70.00
# Weight: 155.00
# Reach: 73.00
# Striking Accuracy: 46%
# Strikes Landed: 7.44
# Strikes Absorbed: 111.00000000000001
# Strike Defense: 73.0
# Takedown Avg: 0.0
# Takedown Accuracy: 31%
# Takedown Defense: 0.0
# Submission Avg: 52.0
# Average Fight Time: 08:26
# KO/TKO Percentage: 77%
# Submission Percentage: 9%
# Decision Percentage: 14%
# Strikes By Standing: 90%
# Strikes By Clinch: 10%
# Strikes By Ground: 0%
# Strikes To Head: 78%
# Strikes To Body: 20%
# Strikes To Legs: 2%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-05/7a8af626-0417-46a8-a875-d23f046d8a97%252FCAMACHO_FRANK_L_05-14.png?itok=OGa-rmMG
# Name: Fabricio Camoes
# Weight Class: Lightweight Division
# Record Text: 14-9-1 (W-L-D)
# Wins: 14, Losses: 9, Draws: 1
# Height: 70.00
# Weight: 158.00
# Reach: 73.00
# Striking Accuracy: 33%
# Strikes Landed: 1.85
# Strikes Absorbed: 234.0
# Strike Defense: 20.0
# Takedown Avg: 1.46
# Takedown Accuracy: 32%
# Takedown Defense: 0.0
# Submission Avg: 61.0
# Average Fight Time: 07:49
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 65%
# Strikes By Clinch: 24%
# Strikes By Ground: 11%
# Strikes To Head: 62%
# Strikes To Body: 17%
# Strikes To Legs: 21%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/8dcdd20b-6da7-4323-9624-fda9543ec780%252FFabricio-Camoes_1133_LeftFullBodyImage.png?itok=j7Q5DSN_
# Name: Brian Camozzi
# Weight Class: Welterweight Division
# Record Text: 7-5-0 (W-L-D)
# Wins: 7, Losses: 5, Draws: 0
# Height: 74.00
# Weight: 171.00
# Reach: 78.00
# Striking Accuracy: 26%
# Strikes Landed: 6.39
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.73
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 55.0
# Average Fight Time: 06:53
# KO/TKO Percentage: 43%
# Submission Percentage: 57%
# Decision Percentage: 0%
# Strikes By Standing: 98%
# Strikes By Clinch: 0%
# Strikes By Ground: 2%
# Strikes To Head: 54%
# Strikes To Body: 17%
# Strikes To Legs: 29%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/1f1bf675-e05f-40ff-a46b-9f29a0db71b2%252Fbrian-camozzi_611147_LeftFullBodyImage.png?itok=rZ4m8AX-
# Name: Chris Camozzi
# Weight Class: Middleweight Division
# Record Text: 24-13-0 (W-L-D)
# Wins: 24, Losses: 13, Draws: 0
# Height: 75.00
# Weight: 186.00
# Reach: 76.00
# Striking Accuracy: 45%
# Strikes Landed: 2.96
# Strikes Absorbed: 27.0
# Strike Defense: 58.0
# Takedown Avg: 0.47
# Takedown Accuracy: 19%
# Takedown Defense: 0.07
# Submission Avg: 56.0
# Average Fight Time: 11:48
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 82%
# Strikes By Clinch: 16%
# Strikes By Ground: 2%
# Strikes To Head: 59%
# Strikes To Body: 16%
# Strikes To Legs: 25%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/cabed0ea-5433-4772-9bbe-6196098290ca%252FChris-Camozzi_1185_LeftFullBodyImage.png?itok=Gt19TMmC
# Name: Ricky Camp
# Weight Class: Bantamweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight:
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Completed page 72
# Name: Shane Campbell
# Weight Class: Lightweight Division
# Record Text: 12-6-0 (W-L-D)
# Wins: 12, Losses: 6, Draws: 0
# Height: 72.00
# Weight: 156.00
# Reach: 71.00
# Striking Accuracy: 60%
# Strikes Landed: 3.19
# Strikes Absorbed: 136.0
# Strike Defense: 82.0
# Takedown Avg: 0.0
# Takedown Accuracy: 29%
# Takedown Defense: 0.0
# Submission Avg: 55.0
# Average Fight Time: 08:50
# KO/TKO Percentage: 42%
# Submission Percentage: 17%
# Decision Percentage: 42%
# Strikes By Standing: 75%
# Strikes By Clinch: 10%
# Strikes By Ground: 15%
# Strikes To Head: 38%
# Strikes To Body: 27%
# Strikes To Legs: 35%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/12d4ebdf-e8d9-43f7-9255-589aeb9f4036%252Fshane-campbell_527986_LeftFullBodyImage.png?itok=p8ZNdmAf
# Name: Charlie Campbell
# Weight Class: Lightweight Division
# Record Text: 9-2-0 (W-L-D)
# Wins: 9, Losses: 2, Draws: 0
# Height: 72.00
# Weight: 170.00
# Reach: 72.50
# Striking Accuracy: 54%
# Strikes Landed: 3.73
# Strikes Absorbed: 295.0
# Strike Defense: 71.0
# Takedown Avg: 0.0
# Takedown Accuracy: 40%
# Takedown Defense: 0.74
# Submission Avg: 55.0
# Average Fight Time: 06:47
# KO/TKO Percentage: 67%
# Submission Percentage: 0%
# Decision Percentage: 33%
# Strikes By Standing: 79%
# Strikes By Clinch: 19%
# Strikes By Ground: 2%
# Strikes To Head: 49%
# Strikes To Body: 29%
# Strikes To Legs: 22%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-04/CAMPBELL_CHARLIE_L_09-16.png?itok=mOLLEHGo
# Name: John Campetella
# Weight Class:
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 0.00
# Weight: 0.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Wagner Campos
# Weight Class: Featherweight Division
# Record Text: 11-4-0 (W-L-D)
# Wins: 11, Losses: 4, Draws: 0
# Height: 66.00
# Weight: 145.00
# Reach:
# Striking Accuracy: 41%
# Strikes Landed: 2.53
# Strikes Absorbed: 271.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 100%
# Takedown Defense: 0.0
# Submission Avg: 52.0
# Average Fight Time: 11:04
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 100%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 29%
# Strikes To Body: 24%
# Strikes To Legs: 47%
# Image URL:
# Name: Will Campuzano
# Weight Class: Flyweight Division
# Record Text: 13-6-0 (W-L-D)
# Wins: 13, Losses: 6, Draws: 0
# Height: 69.00
# Weight: 125.50
# Reach: 70.00
# Striking Accuracy: 32%
# Strikes Landed: 3.82
# Strikes Absorbed: 88.0
# Strike Defense: 48.0
# Takedown Avg: 0.18
# Takedown Accuracy: 45%
# Takedown Defense: 0.0
# Submission Avg: 57.0
# Average Fight Time: 12:11
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 78%
# Strikes By Clinch: 7%
# Strikes By Ground: 15%
# Strikes To Head: 66%
# Strikes To Body: 24%
# Strikes To Legs: 10%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/0fc05923-a63c-4c98-b58b-b11c1a35ea39%252FWill-Campuzano_1118_LeftFullBodyImage.png?itok=9GtT6Hpv
# Name: Aleksa Camur
# Weight Class: Light Heavyweight Division
# Record Text: 6-3-0 (W-L-D)
# Wins: 6, Losses: 3, Draws: 0
# Height: 73.00
# Weight: 204.50
# Reach: 74.00
# Striking Accuracy: 57%
# Strikes Landed: 4.26
# Strikes Absorbed: 46.0
# Strike Defense: 50.0
# Takedown Avg: 0.0
# Takedown Accuracy: 22%
# Takedown Defense: 0.23
# Submission Avg: 54.0
# Average Fight Time: 13:10
# KO/TKO Percentage: 83%
# Submission Percentage: 0%
# Decision Percentage: 17%
# Strikes By Standing: 71%
# Strikes By Clinch: 20%
# Strikes By Ground: 9%
# Strikes To Head: 59%
# Strikes To Body: 30%
# Strikes To Legs: 11%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2021-06/71497%252Fprofile-galery%252Ffullbodyleft-picture%252FCAMUR_ALEKSA_L_06-19.png?itok=VMvEKVg0
# Completed page 73
# Name: Chico Camus
# Weight Class: Flyweight Division
# Record Text: 14-7-0 (W-L-D)
# Wins: 14, Losses: 7, Draws: 0
# Height: 66.00
# Weight: 126.50
# Reach: 66.00
# Striking Accuracy: 41%
# Strikes Landed: 2.46
# Strikes Absorbed: 77.0
# Strike Defense: 72.0
# Takedown Avg: 0.39
# Takedown Accuracy: 40%
# Takedown Defense: 0.0
# Submission Avg: 65.0
# Average Fight Time: 14:36
# KO/TKO Percentage: 33%
# Submission Percentage: 13%
# Decision Percentage: 53%
# Strikes By Standing: 73%
# Strikes By Clinch: 9%
# Strikes By Ground: 18%
# Strikes To Head: 84%
# Strikes To Body: 10%
# Strikes To Legs: 6%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/9555762f-81da-4421-b49b-86872ca2fcea%252FChico-Camus_266911_LeftFullBodyImage.png?itok=0Dw_dIbK
# Name: Asbel Cancio
# Weight Class:
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 0.00
# Weight: 0.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Carlos Candelario
# Weight Class: Flyweight Division
# Record Text: 8-3-0 (W-L-D)
# Wins: 8, Losses: 3, Draws: 0
# Height: 68.00
# Weight: 128.50
# Reach: 68.00
# Striking Accuracy: 47%
# Strikes Landed: 5.17
# Strikes Absorbed: 227.99999999999997
# Strike Defense: 54.0
# Takedown Avg: 0.28
# Takedown Accuracy: 36%
# Takedown Defense: 0.0
# Submission Avg: 44.0
# Average Fight Time: 13:10
# KO/TKO Percentage: 25%
# Submission Percentage: 38%
# Decision Percentage: 38%
# Strikes By Standing: 67%
# Strikes By Clinch: 8%
# Strikes By Ground: 25%
# Strikes To Head: 63%
# Strikes To Body: 21%
# Strikes To Legs: 17%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-05/526c1be0-510d-4326-b67a-adbdb0fe1796%252FCANDELARIO_CARLOS_L_04-30.png?itok=hhk_EdHY
# Name: Ronaldo Candido
# Weight Class: Flyweight Division
# Record Text: 5-2-0 (W-L-D)
# Wins: 5, Losses: 2, Draws: 0
# Height: 67.00
# Weight: 126.00
# Reach:
# Striking Accuracy: 42%
# Strikes Landed: 3.87
# Strikes Absorbed: 800.0
# Strike Defense: 0.0
# Takedown Avg: 5.0
# Takedown Accuracy: 53%
# Takedown Defense: 0.0
# Submission Avg: 52.0
# Average Fight Time: 15:00
# KO/TKO Percentage: 0%
# Submission Percentage: 100%
# Decision Percentage: 0%
# Strikes By Standing: 64%
# Strikes By Clinch: 4%
# Strikes By Ground: 32%
# Strikes To Head: 76%
# Strikes To Body: 12%
# Strikes To Legs: 12%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/56ad3484-660a-4585-8cc2-fea945cead4a%252FRonaldo-Candido_631560_LeftFullBodyImage.png?itok=hWdWjL6Y
# Name: Luiz Cane
# Weight Class: Middleweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 74.00
# Weight: 184.00
# Reach: 77.00
# Striking Accuracy: 42%
# Strikes Landed: 5.0
# Strikes Absorbed: 56.00000000000001
# Strike Defense: 100.0
# Takedown Avg: 0.28
# Takedown Accuracy: 29%
# Takedown Defense: 1.67
# Submission Avg: 61.0
# Average Fight Time: 05:59
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 79%
# Strikes By Clinch: 6%
# Strikes By Ground: 16%
# Strikes To Head: 79%
# Strikes To Body: 12%
# Strikes To Legs: 9%
# Image URL:
# Completed page 74
# Name: Guido Cannetti
# Weight Class: Bantamweight Division
# Record Text: 10-8-0 (W-L-D)
# Wins: 10, Losses: 8, Draws: 0
# Height: 66.00
# Weight: 136.00
# Reach: 68.00
# Striking Accuracy: 55%
# Strikes Landed: 2.84
# Strikes Absorbed: 227.0
# Strike Defense: 65.0
# Takedown Avg: 0.41
# Takedown Accuracy: 55%
# Takedown Defense: 0.0
# Submission Avg: 51.0
# Average Fight Time: 07:16
# KO/TKO Percentage: 40%
# Submission Percentage: 40%
# Decision Percentage: 20%
# Strikes By Standing: 67%
# Strikes By Clinch: 22%
# Strikes By Ground: 12%
# Strikes To Head: 41%
# Strikes To Body: 30%
# Strikes To Legs: 29%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-06/CANNETTI_GUIDO_L_03-11.png?itok=DHYK4n6_
# Name: Jared Cannonier
# Weight Class: Middleweight Division
# Record Text: 18-8-0 (W-L-D)
# Wins: 18, Losses: 8, Draws: 0
# Height: 71.00
# Weight: 185.50
# Reach: 77.50
# Striking Accuracy: 50%
# Strikes Landed: 4.49
# Strikes Absorbed: 46.0
# Strike Defense: 64.0
# Takedown Avg: 0.0
# Takedown Accuracy: 44%
# Takedown Defense: 0.4
# Submission Avg: 57.0
# Average Fight Time: 13:51
# KO/TKO Percentage: 61%
# Submission Percentage: 11%
# Decision Percentage: 28%
# Strikes By Standing: 82%
# Strikes By Clinch: 11%
# Strikes By Ground: 7%
# Strikes To Head: 63%
# Strikes To Body: 20%
# Strikes To Legs: 17%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-02/CANNONIER_JARED_L_02-15.png?itok=nJ2QCV6V
# Name: Steve Cantwell
# Weight Class: Middleweight Division
# Record Text: 7-6-0 (W-L-D)
# Wins: 7, Losses: 6, Draws: 0
# Height: 74.00
# Weight: 185.00
# Reach: 75.00
# Striking Accuracy: 35%
# Strikes Landed: 5.76
# Strikes Absorbed: 65.0
# Strike Defense: 81.0
# Takedown Avg: 0.65
# Takedown Accuracy: 31%
# Takedown Defense: 0.33
# Submission Avg: 55.0
# Average Fight Time: 09:11
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 76%
# Strikes By Clinch: 18%
# Strikes By Ground: 7%
# Strikes To Head: 54%
# Strikes To Body: 32%
# Strikes To Legs: 14%
# Image URL:
# Name: Paul Capaldo
# Weight Class: Bantamweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight:
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Phil Caracappa
# Weight Class: Bantamweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight: 135.50
# Reach:
# Striking Accuracy: 50%
# Strikes Landed: 4.07
# Strikes Absorbed: 100.0
# Strike Defense: 100.0
# Takedown Avg: 1.0
# Takedown Accuracy: 8%
# Takedown Defense: 0.0
# Submission Avg: 29.0
# Average Fight Time: 15:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 27%
# Strikes By Clinch: 70%
# Strikes By Ground: 2%
# Strikes To Head: 27%
# Strikes To Body: 41%
# Strikes To Legs: 32%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/a5255f0f-1c02-4a8e-a07b-021e042bdffc%252FCARACAPPA_PHIL_R.png?itok=lqpK0o0b
# Name: Frank Caracci
# Weight Class: Lightweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 0.00
# Weight: 0.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Completed page 75
# Name: Gina Carano
# Weight Class: Women's Bantamweight Division
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 68.00
# Weight: 135.00
# Reach:
# Striking Accuracy: 47%
# Strikes Landed: 2.66
# Strikes Absorbed: 124.0
# Strike Defense: 86.0
# Takedown Avg: 1.55
# Takedown Accuracy: 67%
# Takedown Defense: 0.62
# Submission Avg: 65.0
# Average Fight Time: 06:03
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 64%
# Strikes By Clinch: 17%
# Strikes By Ground: 19%
# Strikes To Head: 67%
# Strikes To Body: 17%
# Strikes To Legs: 15%
# Image URL:
# Name: Bryan Caraway
# Weight Class: Bantamweight Division
# Record Text: 21-10-0 (W-L-D)
# Wins: 21, Losses: 10, Draws: 0
# Height: 68.00
# Weight: 135.80
# Reach: 68.00
# Striking Accuracy: 34%
# Strikes Landed: 3.61
# Strikes Absorbed: 257.0
# Strike Defense: 81.0
# Takedown Avg: 0.75
# Takedown Accuracy: 26%
# Takedown Defense: 0.0
# Submission Avg: 54.0
# Average Fight Time: 11:04
# KO/TKO Percentage: 10%
# Submission Percentage: 76%
# Decision Percentage: 14%
# Strikes By Standing: 86%
# Strikes By Clinch: 11%
# Strikes By Ground: 3%
# Strikes To Head: 82%
# Strikes To Body: 10%
# Strikes To Legs: 8%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/fighter_images/Bryan_Caraway/CARAWAY_BRYAN_L.png?itok=6_IM3C-X
# Name: Chris Cariaso
# Weight Class: Flyweight Division
# Record Text: 17-8-0 (W-L-D)
# Wins: 17, Losses: 8, Draws: 0
# Height: 63.00
# Weight: 126.00
# Reach: 63.00
# Striking Accuracy: 44%
# Strikes Landed: 2.23
# Strikes Absorbed: 111.00000000000001
# Strike Defense: 58.0
# Takedown Avg: 0.84
# Takedown Accuracy: 39%
# Takedown Defense: 0.0
# Submission Avg: 61.0
# Average Fight Time: 12:28
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 63%
# Strikes By Clinch: 24%
# Strikes By Ground: 12%
# Strikes To Head: 56%
# Strikes To Body: 31%
# Strikes To Legs: 14%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-03/60fc7a7a-9fd1-4b86-ba0d-2eb3a3d51c41%252FChris-Cariaso_1170_LeftFullBodyImage.png?itok=n8urh5Wy
# Name: Rafael Carino
# Weight Class:
# Record Text: 0-0-0 (W-L-D)
# Wins: 0, Losses: 0, Draws: 0
# Height: 0.00
# Weight: 0.00
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0.0
# Strikes Absorbed: 0.0
# Strike Defense: 0.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 0.0
# Average Fight Time: 00:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Name: Antonio Carlos Junior
# Weight Class: Middleweight Division
# Record Text: 11-5-0 (W-L-D)
# Wins: 11, Losses: 5, Draws: 0
# Height: 74.00
# Weight: 185.00
# Reach: 79.00
# Striking Accuracy: 42%
# Strikes Landed: 3.65
# Strikes Absorbed: 292.0
# Strike Defense: 73.0
# Takedown Avg: 2.19
# Takedown Accuracy: 80%
# Takedown Defense: 0.0
# Submission Avg: 40.0
# Average Fight Time: 06:51
# KO/TKO Percentage: 0%
# Submission Percentage: 82%
# Decision Percentage: 18%
# Strikes By Standing: 65%
# Strikes By Clinch: 26%
# Strikes By Ground: 9%
# Strikes To Head: 52%
# Strikes To Body: 26%
# Strikes To Legs: 22%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/ufc-fighter-container/67374/profile-galery/fullbodyleft-picture/CARLOS_JUNIOR_ANTONIO_L.png?VersionId=JGTdyaP_cOJzHbl8eBDqVhbsIehp9EGa&itok=4UFx-vF5
# Completed page 76
# Name: Spike Carlyle
# Weight Class: Featherweight Division
# Record Text: 9-3-0 (W-L-D)
# Wins: 9, Losses: 3, Draws: 0
# Height: 68.00
# Weight: 145.50
# Reach: 71.00
# Striking Accuracy: 54%
# Strikes Landed: 3.85
# Strikes Absorbed: 334.0
# Strike Defense: 57.0
# Takedown Avg: 0.48
# Takedown Accuracy: 37%
# Takedown Defense: 0.0
# Submission Avg: 30.0
# Average Fight Time: 10:28
# KO/TKO Percentage: 56%
# Submission Percentage: 33%
# Decision Percentage: 11%
# Strikes By Standing: 41%
# Strikes By Clinch: 11%
# Strikes By Ground: 48%
# Strikes To Head: 84%
# Strikes To Body: 6%
# Strikes To Legs: 10%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2020-11/71596%252Fprofile-galery%252Ffullbodyleft-picture%252FCARLYLE_SPIKE_L_02-29.png?itok=uw0hEotX
# Name: Francis Carmont
# Weight Class: Middleweight Division
# Record Text: 22-10-0 (W-L-D)
# Wins: 22, Losses: 10, Draws: 0
# Height: 75.00
# Weight: 185.80
# Reach: 78.00
# Striking Accuracy: 42%
# Strikes Landed: 1.64
# Strikes Absorbed: 179.0
# Strike Defense: 73.0
# Takedown Avg: 0.6
# Takedown Accuracy: 37%
# Takedown Defense: 0.12
# Submission Avg: 59.0
# Average Fight Time: 11:20
# KO/TKO Percentage: 27%
# Submission Percentage: 45%
# Decision Percentage: 27%
# Strikes By Standing: 57%
# Strikes By Clinch: 19%
# ...
# Height: 65.00
# Weight: 126.00
# Reach: 65.50
# Striking Accuracy: 48%
# Strikes Landed: 3.02
# Strikes Absorbed: 209.0
# Strike Defense: 62.0
# Takedown Avg: 0.26
# Takedown Accuracy: 46%
# Takedown Defense: 0.0
# Submission Avg: 57.0
# Average Fight Time: 16:26
# KO/TKO Percentage: 9%
# Submission Percentage: 9%
# Decision Percentage: 82%
# Strikes By Standing: 62%
# Strikes By Clinch: 11%
# Strikes By Ground: 27%
# Strikes To Head: 58%
# Strikes To Body: 26%
# Strikes To Legs: 16%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-01/5/CORTEZ_TRACY_L_07-13.png?itok=-KkNuWqg
# Name: Orion Cosce
# Weight Class: Welterweight Division
# Record Text: 8-2-0 (W-L-D)
# Wins: 8, Losses: 2, Draws: 0
# Height: 71.00
# Weight: 172.50
# Reach: 71.00
# Striking Accuracy: 53%
# Strikes Landed: 4.02
# Strikes Absorbed: 192.0
# Strike Defense: 62.0
# Takedown Avg: 0.0
# Takedown Accuracy: 40%
# Takedown Defense: 0.0
# Submission Avg: 44.0
# Average Fight Time: 11:45
# KO/TKO Percentage: 86%
# Submission Percentage: 14%
# Decision Percentage: 0%
# Strikes By Standing: 43%
# Strikes By Clinch: 23%
# Strikes By Ground: 34%
# Strikes To Head: 71%
# Strikes To Body: 18%
# Strikes To Legs: 11%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2023-05/COSCE_ORION_L_05-20.png?itok=g08T3W9M
# Name: Louis Cosce
# Weight Class: Welterweight Division
# Record Text: 7-2-0 (W-L-D)
# Wins: 7, Losses: 2, Draws: 0
# Height: 69.00
# Weight: 170.50
# Reach: 71.00
# Striking Accuracy: 45%
# Strikes Landed: 5.35
# Strikes Absorbed: 104.0
# Strike Defense: 50.0
# Takedown Avg: 0.52
# Takedown Accuracy: 20%
# Takedown Defense: 1.04
# Submission Avg: 48.0
# Average Fight Time: 09:40
# KO/TKO Percentage: 71%
# Submission Percentage: 29%
# Decision Percentage: 0%
# Strikes By Standing: 60%
# Strikes By Clinch: 14%
# Strikes By Ground: 26%
# Strikes To Head: 75%
# Strikes To Body: 14%
# Strikes To Legs: 11%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-09/COSCE_LOUIS_L_09-17.png?itok=ghpdamEA
# Name: Davi Costa
# Weight Class: Unknown
# Record Text: 0-0-0
# Wins: 0, Losses: 0, Draws: 0
# Height:
# Weight:
# Reach:
# Striking Accuracy: 0%
# Strikes Landed: 0
# Strikes Absorbed: 0
# Strike Defense: 0
# Takedown Avg: 0
# Takedown Accuracy: 0%
# Takedown Defense: 0
# Submission Avg: 0
# Average Fight Time: 0
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 0%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 0%
# Strikes To Body: 0%
# Strikes To Legs: 0%
# Image URL:
# Completed page 97
# Name: Alessandro Costa
# Weight Class: Flyweight Division
# Record Text: 14-4-0 (W-L-D)
# Wins: 14, Losses: 4, Draws: 0
# Height: 64.00
# Weight: 140.00
# Reach: 67.00
# Striking Accuracy: 48%
# Strikes Landed: 3.5
# Strikes Absorbed: 27.0
# Strike Defense: 91.0
# Takedown Avg: 0.0
# Takedown Accuracy: 13%
# Takedown Defense: 0.82
# Submission Avg: 58.0
# Average Fight Time: 10:58
# KO/TKO Percentage: 33%
# Submission Percentage: 50%
# Decision Percentage: 17%
# Strikes By Standing: 76%
# Strikes By Clinch: 10%
# Strikes By Ground: 14%
# Strikes To Head: 56%
# Strikes To Body: 20%
# Strikes To Legs: 24%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2024-05/COSTA_ALESSANDRO_L_05-04.png?itok=C0huHc3c
# Name: Paulo Costa
# Weight Class: Middleweight Division
# Record Text: 14-4-0 (W-L-D)
# Wins: 14, Losses: 4, Draws: 0
# Height: 73.00
# Weight: 185.00
# Reach: 72.00
# Striking Accuracy: 58%
# Strikes Landed: 6.56
# Strikes Absorbed: 36.0
# Strike Defense: 80.0
# Takedown Avg: 0.0
# Takedown Accuracy: 75%
# Takedown Defense: 0.48
# Submission Avg: 49.0
# Average Fight Time: 12:32
# KO/TKO Percentage: 85%
# Submission Percentage: 8%
# Decision Percentage: 8%
# Strikes By Standing: 89%
# Strikes By Clinch: 5%
# Strikes By Ground: 6%
# Strikes To Head: 46%
# Strikes To Body: 41%
# Strikes To Legs: 12%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-01/5/COSTA_PAULO_L_06-01.png?itok=qmEdWaiH
# Name: Randy Costa
# Weight Class: Bantamweight Division
# Record Text: 6-4-0 (W-L-D)
# Wins: 6, Losses: 4, Draws: 0
# Height: 69.00
# Weight: 135.00
# Reach: 73.00
# Striking Accuracy: 46%
# Strikes Landed: 7.58
# Strikes Absorbed: 0.0
# Strike Defense: 50.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 1.69
# Submission Avg: 58.0
# Average Fight Time: 04:26
# KO/TKO Percentage: 100%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 89%
# Strikes By Clinch: 8%
# Strikes By Ground: 3%
# Strikes To Head: 82%
# Strikes To Body: 16%
# Strikes To Legs: 2%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2021-07/COSTA_RANDY_L_07-24.png?itok=hm1bt5Ge
# Name: Melquizael Costa
# Weight Class: Featherweight Division
# Record Text: 22-7-0 (W-L-D)
# Wins: 22, Losses: 7, Draws: 0
# Height: 70.00
# Weight: 145.00
# Reach: 71.00
# Striking Accuracy: 46%
# Strikes Landed: 2.22
# Strikes Absorbed: 225.99999999999997
# Strike Defense: 50.0
# Takedown Avg: 1.29
# Takedown Accuracy: 33%
# Takedown Defense: 0.0
# Submission Avg: 59.0
# Average Fight Time: 09:17
# KO/TKO Percentage: 32%
# Submission Percentage: 36%
# Decision Percentage: 32%
# Strikes By Standing: 87%
# Strikes By Clinch: 10%
# Strikes By Ground: 2%
# Strikes To Head: 31%
# Strikes To Body: 44%
# Strikes To Legs: 26%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2025-02/COSTA_MELQUIZAEL_L_06-15.png?itok=yoNLATLJ
# Name: Oscar Cota
# Weight Class: Heavyweight Division
# Record Text: 10-2-0 (W-L-D)
# Wins: 10, Losses: 2, Draws: 0
# Height: 72.00
# Weight: 263.50
# Reach: 72.00
# Striking Accuracy: 42%
# Strikes Landed: 2.47
# Strikes Absorbed: 0.0
# Strike Defense: 60.0
# Takedown Avg: 1.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 41.0
# Average Fight Time: 15:00
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 40%
# Strikes By Clinch: 0%
# Strikes By Ground: 60%
# Strikes To Head: 80%
# Strikes To Body: 0%
# Strikes To Legs: 20%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2020-10/68954%252Fprofile-galery%252Ffullbodyleft-picture%252FCOTA_OSCAR_L.png?itok=6aFpvNss
# Name: Patrick Cote
# Weight Class: Welterweight Division
# Record Text: 24-11-0 (W-L-D)
# Wins: 24, Losses: 11, Draws: 0
# Height: 71.00
# Weight: 170.00
# Reach: 71.00
# Striking Accuracy: 48%
# Strikes Landed: 3.21
# Strikes Absorbed: 68.0
# Strike Defense: 44.0
# Takedown Avg: 0.25
# Takedown Accuracy: 21%
# Takedown Defense: 0.56
# Submission Avg: 49.0
# Average Fight Time: 10:08
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 60%
# Strikes By Clinch: 20%
# Strikes By Ground: 19%
# Strikes To Head: 60%
# Strikes To Body: 16%
# Strikes To Legs: 24%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/ufc-fighter-container/68980/profile-galery/fullbodyleft-picture/Patrick-Cote_334_LeftFullBodyImage.png?VersionId=pxoW2iDojgj.t7T.b.sbuxISSROm45EJ&itok=UfGbFGWN
# Name: J.C. Cottrell
# Weight Class: Lightweight Division
# Record Text: 17-5-0 (W-L-D)
# Wins: 17, Losses: 5, Draws: 0
# Height: 69.00
# Weight: 155.80
# Reach: 71.00
# Striking Accuracy: 25%
# Strikes Landed: 2.75
# Strikes Absorbed: 79.0
# Strike Defense: 50.0
# Takedown Avg: 0.0
# Takedown Accuracy: 100%
# Takedown Defense: 0.0
# Submission Avg: 45.0
# Average Fight Time: 09:27
# KO/TKO Percentage: 12%
# Submission Percentage: 65%
# Decision Percentage: 24%
# Strikes By Standing: 100%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 67%
# Strikes To Body: 7%
# Strikes To Legs: 27%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2020-03/jc-cottrell_598739_LeftFullBodyImage.png?VersionId=cxpBpW1h6UsrjJVN2HdlgExiJ4v8Hdi6&itok=P0Knk_VF
# Completed page 98
# Name: JR Coughran
# Weight Class: Featherweight Division
# Record Text: 4-1-0 (W-L-D)
# Wins: 4, Losses: 1, Draws: 0
# Height:
# Weight: 145.00
# Reach:
# Striking Accuracy: 57%
# Strikes Landed: 6.8
# Strikes Absorbed: 0.0
# Strike Defense: 75.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.0
# Submission Avg: 46.0
# Average Fight Time: 06:55
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 100%
# Strikes By Clinch: 0%
# Strikes By Ground: 0%
# Strikes To Head: 58%
# Strikes To Body: 26%
# Strikes To Legs: 16%
# Image URL:
# Name: Rashad Coulter
# Weight Class: Light Heavyweight Division
# Record Text: 9-4-0 (W-L-D)
# Wins: 9, Losses: 4, Draws: 0
# Height: 71.00
# Weight: 208.00
# Reach: 76.00
# Striking Accuracy: 56%
# Strikes Landed: 6.68
# Strikes Absorbed: 0.0
# Strike Defense: 63.0
# Takedown Avg: 0.0
# Takedown Accuracy: 0%
# Takedown Defense: 0.77
# Submission Avg: 51.0
# Average Fight Time: 07:46
# KO/TKO Percentage: 100%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 68%
# Strikes By Clinch: 30%
# Strikes By Ground: 1%
# Strikes To Head: 79%
# Strikes To Body: 17%
# Strikes To Legs: 4%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/fighter_images/Rashad_Coulter/COULTER_RASHAD_L.png?itok=sQHY0m81
# Name: Randy Couture
# Weight Class: Light Heavyweight Division
# Record Text: 19-11-0 (W-L-D)
# Wins: 19, Losses: 11, Draws: 0
# Height: 74.00
# Weight: 204.00
# Reach: 75.00
# Striking Accuracy: 58%
# Strikes Landed: 1.53
# Strikes Absorbed: 278.0
# Strike Defense: 58.0
# Takedown Avg: 0.48
# Takedown Accuracy: 47%
# Takedown Defense: 0.06
# Submission Avg: 59.0
# Average Fight Time: 12:25
# KO/TKO Percentage: 0%
# Submission Percentage: 0%
# Decision Percentage: 0%
# Strikes By Standing: 29%
# Strikes By Clinch: 30%
# Strikes By Ground: 41%
# Strikes To Head: 75%
# Strikes To Body: 12%
# Strikes To Legs: 13%
# Image URL:
# Name: Ryan Couture
# Weight Class: Lightweight Division
# Record Text: 6-3-0 (W-L-D)
# Wins: 6, Losses: 3, Draws: 0
# Height: 70.00
# Weight: 156.00
# Reach: 75.00
# Striking Accuracy: 45%
# Strikes Landed: 2.87
# Strikes Absorbed: 155.0
# Strike Defense: 47.0
# Takedown Avg: 1.29
# Takedown Accuracy: 29%
# Takedown Defense: 0.0
# Submission Avg: 55.0
# Average Fight Time: 10:49
# KO/TKO Percentage: 17%
# Submission Percentage: 33%
# Decision Percentage: 50%
# Strikes By Standing: 64%
# Strikes By Clinch: 21%
# Strikes By Ground: 15%
# Strikes To Head: 37%
# Strikes To Body: 28%
# Strikes To Legs: 35%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/image/fighter_images/Ryan_Couture/Ryan-Couture-014.png?VersionId=Fa34czi5C1ya_2mtdrciJxYGz0prlldQ&itok=NbRbsKka
# Name: Colby Covington
# Weight Class: Welterweight Division
# Record Text: 17-5-0 (W-L-D)
# Wins: 17, Losses: 5, Draws: 0
# Height: 71.00
# Weight: 171.00
# Reach: 72.00
# Striking Accuracy: 38%
# Strikes Landed: 3.09
# Strikes Absorbed: 364.0
# Strike Defense: 69.0
# Takedown Avg: 0.16
# Takedown Accuracy: 43%
# Takedown Defense: 0.05
# Submission Avg: 55.0
# Average Fight Time: 16:57
# KO/TKO Percentage: 24%
# Submission Percentage: 24%
# Error scraping fighter /athlete/colby-covington: 'NoneType' object has no attribute 'text'
# Name: Hailey Cowan
# Weight Class: Women's Bantamweight Division
# Record Text: 7-3-0 (W-L-D)
# Wins: 7, Losses: 3, Draws: 0
# Height: 68.00
# Weight: 137.50
# Reach: 67.00
# Striking Accuracy: 42%
# Strikes Landed: 3.17
# Strikes Absorbed: 150.0
# Strike Defense: 80.0
# Takedown Avg: 0.0
# Takedown Accuracy: 33%
# Takedown Defense: 0.0
# Submission Avg: 34.0
# Average Fight Time: 15:00
# KO/TKO Percentage: 29%
# Submission Percentage: 29%
# Decision Percentage: 43%
# Strikes By Standing: 57%
# Strikes By Clinch: 29%
# Strikes By Ground: 13%
# Strikes To Head: 58%
# Strikes To Body: 37%
# Strikes To Legs: 4%
# Image URL: https://ufc.com/images/styles/athlete_bio_full_body/s3/2022-08/COWAN_HAILEY_L.png?itok=GdczbP4d
# Completed page 99
# Scraped 504 fighters successfully!
# Completed scraping 504 fighters.
#                       id                 name                    weightClass  \
# 0    shamil-abdurakhimov  Shamil Abdurakhimov           Heavyweight Division
# 1             daichi-abe           Daichi Abe          Welterweight Division
# 2             papy-abedi           Papy Abedi          Middleweight Division
# 3          ricardo-abreu        Ricardo Abreu          Middleweight Division
# 4          klidson-abreu        Klidson Abreu     Light Heavyweight Division
# ..                   ...                  ...                            ...
# 499        jr-coughran-0          JR Coughran         Featherweight Division
# 500       rashad-coulter       Rashad Coulter     Light Heavyweight Division
# 501        randy-couture        Randy Couture     Light Heavyweight Division
# 502         ryan-couture         Ryan Couture           Lightweight Division
# 503         hailey-cowan         Hailey Cowan  Women's Bantamweight Division
#
#      wins  losses  draws height  weight  reach  strikesLandedPerMin  ...  \
# 0      20       8      0  75.00  263.00  76.00                 3.02  ...
# 1       6       1      0  69.00  170.50  71.50                 4.49  ...
# 2       9       3      0  71.00  184.50  74.00                 3.15  ...
# 3       5       1      0  71.00  183.00  73.00                 3.98  ...
# 4      15       4      0  74.00  206.00  74.00                 2.90  ...
# ..    ...     ...    ...    ...     ...    ...                  ...  ...
# 499     4       1      0         145.00                        6.80  ...
# 500     9       4      0  71.00  208.00  76.00                 6.68  ...
# 501    19      11      0  74.00  204.00  75.00                 1.53  ...
# 502     6       3      0  70.00  156.00  75.00                 2.87  ...
# 503     7       3      0  68.00  137.50  67.00                 3.17  ...
#
#     KoTkoPercentage  SubmissionPercentage  DecisionPercentage  \
# 0               45%                   20%                 35%
# 1               67%                    0%                 33%
# 2               56%                   22%                 22%
# 3               60%                   40%                  0%
# 4               27%                   67%                  7%
# ..              ...                   ...                 ...
# 499              0%                    0%                  0%
# 500            100%                    0%                  0%
# 501              0%                    0%                  0%
# 502             17%                   33%                 50%
# 503             29%                   29%                 43%
#
#      StrikesByStanding StrikesByClinching  StrikesByGround  StrikesToHead  \
# 0                  67%                24%               9%            59%
# 1                  85%                 6%               8%            60%
# 2                  37%                35%              28%            43%
# 3                  73%                16%              11%            81%
# 4                  90%                10%               0%            40%
# ..                 ...                ...              ...            ...
# 499               100%                 0%               0%            58%
# 500                68%                30%               1%            79%
# 501                29%                30%              41%            75%
# 502                64%                21%              15%            37%
# 503                57%                29%              13%            58%
#
#     StrikesToBody StrikesToLegs  \
# 0             19%           22%
# 1              7%           33%
# 2             47%            9%
# 3             13%            6%
# 4             21%           40%
# ..            ...           ...
# 499           26%           16%
# 500           17%            4%
# 501           12%           13%
# 502           28%           35%
# 503           37%            4%
#
#                                                  image
# 0    https://ufc.com/images/styles/athlete_bio_full...
# 1    https://ufc.com/images/styles/athlete_bio_full...
# 2    https://ufc.com/images/styles/athlete_bio_full...
# 3    https://ufc.com/images/styles/athlete_bio_full...
# 4    https://ufc.com/images/styles/athlete_bio_full...
# ..                                                 ...
# 499
# 500  https://ufc.com/images/styles/athlete_bio_full...
# 501
# 502  https://ufc.com/images/styles/athlete_bio_full...
# 503  https://ufc.com/images/styles/athlete_bio_full...
#
# [504 rows x 28 columns]
# Data saved to fighters_data.csv

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
import joblib
import numpy as np
from IPython.display import display, clear_output
import ipywidgets as widgets
import requests

# Load the CSV file into a DataFrame
dataset = pd.read_csv('fighters_data.csv')

# Handle missing values for descriptive columns
dataset['weightClass'] = dataset['weightClass'].fillna(dataset['weightClass'].mode().iloc[0])

# Convert percentage columns to numeric by removing '%' sign and dividing by 100
percentage_columns = ['strikingAccuracy', 'takedownAccuracy', 'KoTkoPercentage',
                      'SubmissionPercentage', 'DecisionPercentage', 'StrikesByStanding',
                      'StrikesByClinching', 'StrikesByGround', 'StrikesToHead', 'StrikesToBody',
                      'StrikesToLegs']

for col in percentage_columns:
    if col in dataset.columns:
        dataset[col] = dataset[col].str.replace('%', '').astype(float) / 100

# Convert avgFightTime from min:secs to seconds
def convert_time_to_seconds(time_str):
    try:
        minutes, seconds = map(int, time_str.split(':'))
        return minutes * 60 + seconds
    except:
        return np.nan

if 'avgFightTime' in dataset.columns:
    dataset['avgFightTime'] = dataset['avgFightTime'].apply(convert_time_to_seconds)

# List of numeric columns to normalize
numeric_columns = [
    'height', 'weight', 'reach', 'strikesLandedPerMin', 'strikingAccuracy',
    'strikesAbsorbedPerMin', 'strikeDefense', 'takedownAvgPer15Min',
    'takedownAccuracy', 'takedownDefense', 'submissionAvgPer15Min',
    'avgFightTime', 'KoTkoPercentage', 'SubmissionPercentage',
    'DecisionPercentage', 'StrikesByStanding', 'StrikesByClinching',
    'StrikesByGround', 'StrikesToHead', 'StrikesToBody', 'StrikesToLegs',
    'wins', 'losses', 'draws'
]

# Convert other numeric columns to numeric, coercing errors to NaN
dataset[numeric_columns] = dataset[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Identify columns that are all NaN
all_nan_columns = dataset.columns[dataset.isna().all()].tolist()

# Drop columns that are all NaN
dataset = dataset.dropna(axis=1, how='all')

# Preserve original values before normalization
original_dataset = dataset.copy()

# Fill missing values in numeric columns with the mean
dataset[numeric_columns] = dataset[numeric_columns].fillna(dataset[numeric_columns].mean())

# Normalize the numeric columns using Min-Max scaling
scaler = MinMaxScaler()
dataset[numeric_columns] = scaler.fit_transform(dataset[numeric_columns])

# Select features and target variable for modeling
features = numeric_columns
# Assuming a placeholder target variable with int type for classification
dataset['target'] = (dataset['wins'] > dataset['losses']).astype(int)

# Split the data into features and target
X = dataset[features]
y = dataset['target']

# Initialize the Random Forest model
model = RandomForestClassifier(random_state=42)

# Train the model
model.fit(X, y)

# Save the trained model
joblib.dump(model, 'ufc_fight_predictor.pkl')

# Function to get fighter stats as per the dataset
def get_fighter_stats(fighter_name):
    fighter_name = fighter_name.strip().lower()
    fighter = original_dataset[original_dataset['name'].str.lower() == fighter_name]
    if not fighter.empty:
        return fighter.iloc[0], dataset[dataset['name'].str.lower() == fighter_name][features].values[0]
    return None, None

# Function to predict fight outcome
def predict_fight_outcome(fighter1_name, fighter2_name):
    fighter1_data, stats1 = get_fighter_stats(fighter1_name)
    fighter2_data, stats2 = get_fighter_stats(fighter2_name)
    if stats1 is not None and stats2 is not None:
        combined_stats = np.abs(stats1 - stats2)
        combined_stats_df = pd.DataFrame([combined_stats], columns=features)
        prediction = model.predict(combined_stats_df)[0]

        if prediction == 1:
            winner = fighter1_name
            win_method = determine_win_method(fighter1_data, fighter2_data)
        else:
            winner = fighter2_name
            win_method = determine_win_method(fighter2_data, fighter1_data)

        return winner, win_method
    else:
        return None, None

# Function to determine the win method
def determine_win_method(winner_data, loser_data):
    ko_diff = winner_data['KoTkoPercentage'] - loser_data['KoTkoPercentage']
    sub_diff = winner_data['SubmissionPercentage'] - loser_data['SubmissionPercentage']
    dec_diff = winner_data['DecisionPercentage'] - loser_data['DecisionPercentage']

    if ko_diff > sub_diff and ko_diff > dec_diff:
        return 'knockout'
    elif sub_diff > ko_diff and sub_diff > dec_diff:
        return 'submission'
    else:
        return 'decision'

# Create UI elements
weight_classes = dataset['weightClass'].unique()
fighters_by_weight_class = {wc: original_dataset[original_dataset['weightClass'] == wc] for wc in weight_classes}

weight_class_dropdown = widgets.Dropdown(
    options=weight_classes,
    description='Weight Class:'
)

fighter1_dropdown = widgets.Dropdown(
    options=[],
    description='Fighter 1:'
)

fighter2_dropdown = widgets.Dropdown(
    options=[],
    description='Fighter 2:'
)

# Ensure that fighter dropdowns are populated with the default weight class fighters when the code is first executed
def initialize_fighter_dropdowns():
    selected_weight_class = weight_class_dropdown.value  # Get the default value of the weight class dropdown
    fighters = fighters_by_weight_class[selected_weight_class]['name'].values
    fighter1_dropdown.options = fighters
    fighter2_dropdown.options = fighters

# Call the function to initialize the fighter dropdowns

initialize_fighter_dropdowns()

def update_fighter_dropdowns(change):
    selected_weight_class = change['new']
    fighters = fighters_by_weight_class[selected_weight_class]['name'].values
    fighter1_dropdown.options = fighters
    fighter2_dropdown.options = fighters

weight_class_dropdown.observe(update_fighter_dropdowns, names='value')

predict_button = widgets.Button(description='Predict')
output = widgets.Output()

def is_valid_url(url):
    try:
        result = requests.get(url)
        return result.status_code == 200
    except:
        return False

def display_prediction_result(fighter1_data, fighter2_data, prediction_result, win_method):
    with output:
        clear_output()

        fighter1_img = widgets.Image(value=requests.get(fighter1_data['image']).content) if is_valid_url(fighter1_data['image']) else widgets.Label("No Image")
        fighter2_img = widgets.Image(value=requests.get(fighter2_data['image']).content) if is_valid_url(fighter2_data['image']) else widgets.Label("No Image")

        fighter1_info = widgets.HTML(f"""
            <h3>{fighter1_data['name']}</h3>
            <p>Record: {fighter1_data['wins']} wins, {fighter1_data['losses']} losses, {fighter1_data['draws']} draws</p>
            <p>Height: {fighter1_data['height']} inches</p>
            <p>Weight: {fighter1_data['weight']} lbs</p>
            <p>Reach: {fighter1_data['reach']} inches</p>
            <p>KO/TKO Percentage: {fighter1_data['KoTkoPercentage']*100}%</p>
            <p>Submission Percentage: {fighter1_data['SubmissionPercentage']*100}%</p>
            <p>Decision Percentage: {fighter1_data['DecisionPercentage']*100}%</p>
        """)

        fighter2_info = widgets.HTML(f"""
            <h3>{fighter2_data['name']}</h3>
            <p>Record: {fighter2_data['wins']} wins, {fighter2_data['losses']} losses, {fighter2_data['draws']} draws</p>
            <p>Height: {fighter2_data['height']} inches</p>
            <p>Weight: {fighter2_data['weight']} lbs</p>
            <p>Reach: {fighter2_data['reach']} inches</p>
            <p>KO/TKO Percentage: {fighter2_data['KoTkoPercentage']*100}%</p>
            <p>Submission Percentage: {fighter2_data['SubmissionPercentage']*100}%</p>
            <p>Decision Percentage: {fighter2_data['DecisionPercentage']*100}%</p>
        """)

        display(widgets.HBox([widgets.VBox([fighter1_img, fighter1_info]), widgets.VBox([fighter2_img, fighter2_info])]))

        if prediction_result:
            winner_data = fighters_by_weight_class[weight_class_dropdown.value][fighters_by_weight_class[weight_class_dropdown.value]['name'] == prediction_result].iloc[0]
            winner_img = widgets.Image(value=requests.get(winner_data['image']).content) if is_valid_url(winner_data['image']) else widgets.Label("No Image")
            winner_info = widgets.HTML(f"""
                <h3>Predicted Winner: {prediction_result}</h3>
                <p>{prediction_result} wins by {win_method}</p>
            """)
            display(widgets.HBox([winner_img, winner_info]))

def on_predict_button_clicked(b):
    fighter1_name = fighter1_dropdown.value
    fighter2_name = fighter2_dropdown.value

    with output:
        clear_output()

        # Check if the same fighter is selected in both dropdowns
        if fighter1_name == fighter2_name:
            display(widgets.HTML(f"<h3 style='color: red;'>A fighter cannot fight himself in the ring, but only in mind!</h3>"))
        else:
            # Proceed with prediction if different fighters are selected
            fighter1_data, _ = get_fighter_stats(fighter1_name)
            fighter2_data, _ = get_fighter_stats(fighter2_name)

            prediction_result, win_method = predict_fight_outcome(fighter1_name, fighter2_name)

            display_prediction_result(fighter1_data, fighter2_data, prediction_result, win_method)

predict_button.on_click(on_predict_button_clicked)

display(weight_class_dropdown, fighter1_dropdown, fighter2_dropdown, predict_button, output)
# Out:
# Dropdown(description='Weight Class:', options=('Heavyweight Division', 'Welterweight Division', 'Middleweight …
# Dropdown(description='Fighter 1:', options=('Shamil Abdurakhimov', 'Scott Adams', 'Juan Adams', 'Mostapha Al T…
# Dropdown(description='Fighter 2:', options=('Shamil Abdurakhimov', 'Scott Adams', 'Juan Adams', 'Mostapha Al T…
# Button(description='Predict', style=ButtonStyle())
# Output()
